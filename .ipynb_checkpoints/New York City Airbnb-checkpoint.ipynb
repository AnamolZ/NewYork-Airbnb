# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'C:\\Users\\anmol\\OneDrive - Leeds Beckett University\\Organized Files\\Python Project\\Jupyter\\AB_NYC_2019.csv'

# %%
df = pd.read_csv(path)

# %%
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
x = df['price'][:10]
y = df['minimum_nights'][:10]

# %%
plt.plot(x, color='red', label='X Data')
plt.plot(y, color='blue', label='Y Data')
plt.show()

# %%
host_id = df['host_id']
reviews_per_month = df['reviews_per_month']
# room_type = df['room_type']
price = df['price']
minimum_nights = df['minimum_nights']
availability_365 = df['availability_365']

# %%
# plt.plot(reviews_per_month,color='red')
# plt.plot(price, color='green')
# plt.plot(minimum_nights, color='blue')

reviews_per_month = df['reviews_per_month'].iloc[:10]
price = df['price'].iloc[:10]
minimum_nights = df['minimum_nights'].iloc[:10]

# colors = ['red', 'green', 'blue']

colors = ['red', 'blue']

plt.scatter(np.arange(len(reviews_per_month)), reviews_per_month, c=colors[0], label='reviews_per_month')
# plt.scatter(np.arange(len(price)), price, c=colors[1], label='price')
plt.scatter(np.arange(len(minimum_nights)), minimum_nights, c=colors[1], label='minimum_nights')

# plt.ylim([0, max(max(reviews_per_month), max(price), max(minimum_nights))])

plt.ylim([0, 12])

plt.legend()

plt.show()

# %%
img_path = 'C:\\Users\\anmol\\OneDrive - Leeds Beckett University\\Organized Files\\Python Project\\Jupyter\\New_York_City_.png'
img = Image.open(img_path)

# %%
map_img = np.array(img)

# %%
xmin, xmax = df['longitude'].min(), df['longitude'].max()
ymin, ymax = df['latitude'].min(), df['latitude'].max()

# %%
plt.imshow(map_img, extent=[xmin, xmax, ymin, ymax])

# %%
plt.scatter(x=df['longitude'], y=df['latitude'], color='red', s=1)
plt.show()
